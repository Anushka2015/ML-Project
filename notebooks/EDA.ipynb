# %% [markdown]
# Diamond Price Prediction
# Introduction About the Data :
# The dataset The goal is to predict price of given diamond (Regression Analysis).
#
# There are 10 independent variables (including id):
#
# id : unique identifier of each diamond
# carat : Carat (ct.) refers to the unique unit of weight measurement used exclusively to weigh gemstones and diamonds.
# cut : Quality of Diamond Cut
# color : Color of Diamond
# clarity : Diamond clarity is a measure of the purity and rarity of the stone, graded by the visibility of these characteristics under 10-power magnification.
# depth : The depth of diamond is its height (in millimeters) measured from the culet (bottom tip) to the table (flat, top surface)
# table : A diamond's table is the facet which can be seen when the stone is viewed face up.
# x : Diamond X dimension
# y : Diamond Y dimension
# x : Diamond Z dimension
# Target variable:
#
# price: Price of the given Diamond.
# Dataset Source Link : https://www.kaggle.com/competitions/playground-series-s3e8/data?select=train.csv

# %%
import pandas as pd

# %%
## Data Ingestions step
df=pd.read_csv("https://raw.githubusercontent.com/krishnaik06/FSDSRegression/main/notebooks/data/gemstone.csv")
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df_new = df.copy()

# %%
df_new.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %% [markdown]
# No missing value present in data

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
###Drop the id column as it is not really relevent to data
df_new=df_new.drop(labels=["id"],axis=1)

# %%
df_new.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
###check duplicated records
df_new.duplicated().sum()
# Out:
# 0

# %%
##segregate numerical and categorical colums
numerical_columns=df_new.columns[df_new.dtypes!="object"]

# %%
categorical_columns=df_new.columns[df_new.dtypes=="object"]

# %%
print("numerical_columns:", numerical_columns)
print("categorical_columns:", categorical_columns)
# Out:
# numerical_columns: Index(['carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')
# categorical_columns: Index(['cut', 'color', 'clarity'], dtype='object')

# %%
df_new[categorical_columns].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
df_new["cut"].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
df_new["cut"].value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
df_new["color"].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
df_new["clarity"].value_counts()
# Out:
# clarity
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
x=0
for i in numerical_columns:
    sns.histplot(data=df_new,x=i,kde=True)
    print('\n')
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
x=0
for i in categorical_columns:
    sns.countplot(data=df_new,x=i)
    print('\n')
    plt.show()

# %%
## correlation
sns.heatmap(df_new.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
###df_new.drop(labels=["x","y","z"],axis=1)
# execute it later

# %%
df1=df_new.sample(50)

# %%
df1
# Out:
#         carat        cut color clarity  depth  table     x     y     z  price
# 91160    0.50      Ideal     E     VS2   62.1   57.0  5.06  5.09  3.16   1637
# 113526   0.32      Ideal     D     SI1   62.2   54.0  4.38  4.39  2.73    756
# 71662    0.30      Ideal     F      IF   62.0   55.0  4.31  4.34  2.68    886
# 99386    0.70    Premium     F     SI1   61.8   55.0  5.73  5.71  3.54   2391
# 126251   0.71      Ideal     F     SI2   62.0   56.0  5.73  5.76  3.56   2056
# 74266    0.90      Ideal     F     SI1   62.3   57.0  6.20  6.14  3.84   3918
# 45385    0.55      Ideal     E     SI2   62.2   56.0  5.26  5.29  3.28   1435
# 139567   0.30      Ideal     G    VVS1   61.5   57.0  4.31  4.33  2.65    790
# 62506    1.52    Premium     E     VS1   60.4   59.0  7.48  7.46  4.51  13767
# 190477   0.70    Premium     F     VS1   61.0   60.0  5.74  5.67  3.49   2801
# 136998   0.31      Ideal     G     VS2   61.1   56.0  4.35  4.38  2.67    490
# 183476   0.50       Fair     F     SI2   66.5   62.0  4.92  4.83  3.25    992
# 125430   1.01    Premium     F     SI1   60.5   59.0  6.46  6.40  3.88   4989
# 34990    1.11      Ideal     H     SI1   62.0   57.0  6.68  6.64  4.13   5646
# 121879   0.31    Premium     H     SI1   62.4   57.0  4.30  4.32  2.69    558
# 159049   0.72    Premium     H     VS2   61.3   59.0  5.77  5.74  3.53   2462
# 135614   0.70       Good     I     VS2   64.1   56.0  5.59  5.62  3.60   2136
# 131968   0.70      Ideal     H     SI1   62.6   56.0  5.66  5.68  3.55   2219
# 143373   1.01       Good     E     SI1   63.9   58.0  6.38  6.31  4.06   5335
# 103882   0.92    Premium     G     SI1   59.9   59.0  6.37  6.34  3.80   4167
# 170346   0.42      Ideal     E     SI2   62.0   55.0  4.77  4.81  2.97    692
# 22339    0.45      Ideal     D     VS1   62.9   57.0  4.82  4.86  3.05   1248
# 139733   0.90  Very Good     H     SI1   62.5   63.0  6.13  6.05  3.79   3192
# 72756    0.56      Ideal     H     VS2   61.5   55.0  5.30  5.33  3.28   1728
# 59518    0.38    Premium     G     VS1   61.3   60.0  4.68  4.72  2.86   1040
# 70022    1.02      Ideal     D     SI1   61.0   56.0  6.56  6.51  3.99   6439
# 82297    0.70    Premium     F     SI1   60.2   58.0  5.74  5.77  3.47   2609
# 17367    1.02      Ideal     G     SI2   61.3   56.0  6.51  6.54  4.00   4202
# 175016   0.70    Premium     I     SI1   61.8   58.0  5.68  5.65  3.51   2026
# 111734   0.38    Premium     D     SI1   61.5   58.0  4.67  4.63  2.86    750
# 98571    0.30       Good     F     SI1   64.2   57.0  4.29  4.27  2.75    475
# 158705   0.53      Ideal     E     SI2   61.0   55.0  5.24  5.20  3.19   1145
# 136692   0.32      Ideal     G      IF   61.9   55.0  4.40  4.42  2.73    918
# 44648    0.34      Ideal     F     VS2   61.7   56.0  4.48  4.46  2.76    880
# 158125   0.60      Ideal     G    VVS1   61.1   56.0  5.41  5.47  3.32   2005
# 113336   0.30      Ideal     D     VS2   62.0   55.0  4.33  4.35  2.69    710
# 125886   0.71      Ideal     D     SI1   61.9   57.0  5.68  5.72  3.53   2112
# 183158   0.44  Very Good     G     SI1   63.1   58.0  4.80  4.78  3.03    990
# 72889    0.53      Ideal     E     VS2   61.6   55.0  5.21  5.21  3.21   1614
# 31621    0.42      Ideal     D     SI1   61.1   56.0  4.85  4.83  2.95    792
# 10921    0.35      Ideal     I     SI1   61.2   57.0  4.52  4.56  2.78    572
# 151361   0.70  Very Good     E     SI1   62.9   59.0  5.63  5.65  3.55   2753
# 35155    2.01  Very Good     I     SI2   63.6   60.0  7.89  7.97  5.05  11574
# 113786   0.52      Ideal     E     VS2   61.7   55.0  5.20  5.16  3.20   1815
# 125280   1.01  Very Good     H     SI1   61.2   60.0  6.34  6.42  3.91   4386
# 53637    0.70    Premium     J     SI1   61.3   61.0  5.68  5.71  3.49   1814
# 38051    0.70      Ideal     H     VS2   62.1   57.0  5.70  5.65  3.52   1890
# 10710    0.70    Premium     H      IF   61.1   56.0  5.75  5.68  3.49   2882
# 26440    1.01  Very Good     I     SI1   63.3   58.0  6.38  6.31  4.01   3902
# 191812   0.51      Ideal     E     VS2   61.8   57.0  5.11  5.15  3.17   1607

# %%
sns.pairplot(df1)

# %%
df_new['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
cut_map={"Fair":1,"Good":2,"Very Good":3,"Premium":4,"Ideal":5}

# %%
df_new['clarity'].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
clarity_map = {"I1":1,"SI2":2 ,"SI1":3 ,"VS2":4 , "VS1":5 , "VVS2":6 , "VVS1":7 ,"IF":8}

# %%
df_new['color'].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
color_map = {"D":1 ,"E":2 ,"F":3 , "G":4 ,"H":5 , "I":6, "J":7}

# %%
df_new['cut']=df_new['cut'].map(cut_map)
df_new['clarity'] = df_new['clarity'].map(clarity_map)
df_new['color'] = df_new['color'].map(color_map)

# %%
df_new.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z  price
# 0   1.52    4      3        4   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03    3      7        2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70    5      4        5   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32    5      4        5   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    4      4        4   62.6   59.0  7.65  7.61  4.77  14453
